# %%
import pandas as pd
import numpy as np
data=pd.read_csv('/content/Lab4.csv')
attribute=np.array(data)[:,:-1]
target=np.array(data)[:,-1]
print("Training data:\n")
print(data)
def train(att,tar):
  for i,val in enumerate(tar):
    if val=='yes':
      specific_h=att[i].copy()
      break
    for i,val in  enumerate(att):
     if tar[i]=='yes':
        for x in range(len(specific_h)):
            if val[x]!=specific_h[x]:
              specific_h[x]='?'
            else:
                pass
            return specific_h
            print("\n")
            print(train(attribute,target))
# Out:
# Training data:
#
#      sky air_temp humidity    wind forecast enjoy_sport
# 0  sunny     warm   normal  strong     warm         yes
# 1  sunny     warm     high  strong     warm         yes
# 2  rainy     cold     high  strong     warm          no
# 3  sunny     warm     high  strong     cold         yes
