# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing 
california_data=fetch_california_housing(as_frame=True)
data=california_data.frame
correlation_matrix=data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap='BuPu',fmt='.2f',linewidths=1.5)
plt.title('Corrilation matrix of california hosing features')
plt.show()
sns.pairplot(data,diag_kind='kde',plot_kws={'alpha':0.5})
plt.suptitle('pair plot of california hosing feature ',y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-437155956.py in <cell line: 0>()
#      11 plt.title('Corrilation matrix of california hosing features')
#      12 plt.show()
# ---> 13 sns.parplot(data,diag_kind='kde',plot_kws={'alpha':0.5})
#      14 plt.suptitle('pair plot of california hosing feature ',y=1.02)
#      15 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'parplot'
